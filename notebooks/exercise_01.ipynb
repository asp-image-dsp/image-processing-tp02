# %% [markdown]
# # Ejercicio 01

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
import PIL

# %%
import cv2

# %% [markdown]
# ## Cargando la imagen de la **rosa**

# %%
img_rose = cv2.imread('../resources/rose.tif', cv2.IMREAD_GRAYSCALE)

# %%
plt.figure(figsize=(5, 5))
plt.imshow(img_rose, cmap='gray')
plt.axis('off')
plt.show()

# %% [markdown]
# ## Decimación de la **rosa**

# %%
decimation_img_rose = [
    cv2.resize(img, (0, 0), fx=1/(2**i), fy=1/(2**i), interpolation=cv2.INTER_NEAREST)
    for i in range(0, 6)
]

# %%
for i in range(len(decimation_img_rose)):
    plt.figure(figsize=(8 / 2**i, 8 / 2**i))
    plt.imshow(decimation_img_rose[i], cmap='gray')
    plt.title(f'Resolución {1024 // 2**i} x {1024 // 2**i}', fontsize=18)
    plt.axis('off')

# %%
fig, ax = plt.subplots(2, 3, figsize=(15, 10))
ax = ax.reshape(-1)
for i in range(len(decimation_img_rose)):
    ax[i].imshow(decimation_img_rose[i], cmap='gray')
    ax[i].set_title(f'Resolución {1024 // 2**i} x {1024 // 2**i}', fontsize=18)
    ax[i].axis('off')

# %% [markdown]
# ## Cargando la imagen del **cráneo**

# %%
img_skull = cv2.imread('../resources/skull.tif', cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(img_skull, cmap='gray')
plt.show()

# %% [markdown]
# ## Cuantización del **cráneo**

# %%
def quantize(image, from_levels, to_levels):
    """ Converts the amount of color levels used to represent an image, modifying its quantization levels.
        @param image Image to be converted
        @param from_levels Current amount of color levels
        @param to_levels New amount of color levels
        @return New image
    """
    to_levels = to_levels - 1
    from_levels = from_levels - 1
    return np.round(image * (to_levels / from_levels)) * (from_levels / to_levels)

# %%
quantization_img_skull = [
    quantize(img_skull, 256, 2 ** i)
    for i in range(1, 9)
]

# %%
fig, ax = plt.subplots(2, 4, figsize=(16, 10))
ax = ax.reshape(-1)
for i in range(len(quantization_img_skull)):
    ax[i].imshow(quantization_img_skull[i], cmap='gray')
    ax[i].set_title(f'{2**(i + 1)} niveles', fontsize=18)
    ax[i].axis('off')
